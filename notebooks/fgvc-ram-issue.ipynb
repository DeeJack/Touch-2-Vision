# %% [markdown]
# Install conda on the Colab instance

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/condacolab.py:27
#      26 try:
# ---> 27     import google.colab
#      28 except ImportError:
#
# ModuleNotFoundError: No module named 'google.colab'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 2
#       1 get_ipython().system('pip install -q condacolab')
# ----> 2 import condacolab
#       3 condacolab.install()
#
# File /opt/conda/lib/python3.10/site-packages/condacolab.py:29
#      27     import google.colab
#      28 except ImportError:
# ---> 29     raise RuntimeError("This module must ONLY run as part of a Colab notebook!")
#      32 __version__ = "0.1.9"
#      33 __author__ = "Jaime Rodríguez-Guerra <jaimergp@users.noreply.github.com>"
#
# RuntimeError: This module must ONLY run as part of a Colab notebook!

# %% [markdown]
# Check conda installation

# %%
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %% [markdown]
# Clone the Flow-edge Guided Video Completion repository

# %%
# !git clone https://github.com/vt-vl-lab/FGVC
# %cd FGVC
# Out:
# Cloning into 'FGVC'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 138 (delta 17), reused 35 (delta 9), pack-reused 90
# Receiving objects: 100% (138/138), 89.42 KiB | 1.94 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
# /kaggle/working/FGVC

# %% [markdown]
# Install dependencies

# %%
# %cd FGVC/
# !conda create --prefix=.conda python=3.8.5 -y
# !conda init
# Out:
# [Errno 2] No such file or directory: 'FGVC/'
# /kaggle/working/FGVC
# Channels:
#  - rapidsai
#  - nvidia
#  - conda-forge
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /kaggle/working/FGVC/.conda
#
#   added / updated specs:
#     - python=3.8.5
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     ld_impl_linux-64-2.40      |       hf3520f5_7         691 KB  conda-forge
#     libffi-3.2.1               |    he1b5a44_1007          47 KB  conda-forge
#     libgcc-ng-14.1.0           |       h77fa898_0         822 KB  conda-forge
#     libgomp-14.1.0             |       h77fa898_0         446 KB  conda-forge
#     libstdcxx-ng-14.1.0        |       hc0a3c3a_0         3.7 MB  conda-forge
#     libzlib-1.2.13             |       h4ab18f5_6          60 KB  conda-forge
#     ncurses-6.5                |       h59595ed_0         867 KB  conda-forge
#     openssl-1.1.1w             |       hd590300_0         1.9 MB  conda-forge
#     pip-24.0                   |     pyhd8ed1ab_0         1.3 MB  conda-forge
#     python-3.8.5               |h1103e12_9_cpython        21.9 MB  conda-forge
#     setuptools-71.0.4          |     pyhd8ed1ab_0         1.4 MB  conda-forge
#     sqlite-3.46.0              |       h6d4b2fc_0         840 KB  conda-forge
#     wheel-0.43.0               |     pyhd8ed1ab_1          57 KB  conda-forge
#     zlib-1.2.13                |       h4ab18f5_6          91 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        34.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   ca-certificates    conda-forge/linux-64::ca-certificates-2024.7.4-hbcca054_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.40-hf3520f5_7
#   libffi             conda-forge/linux-64::libffi-3.2.1-he1b5a44_1007
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-14.1.0-h77fa898_0
#   libgomp            conda-forge/linux-64::libgomp-14.1.0-h77fa898_0
#   libsqlite          conda-forge/linux-64::libsqlite-3.46.0-hde9e2c9_0
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-14.1.0-hc0a3c3a_0
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-h4ab18f5_6
#   ncurses            conda-forge/linux-64::ncurses-6.5-h59595ed_0
#   openssl            conda-forge/linux-64::openssl-1.1.1w-hd590300_0
#   pip                conda-forge/noarch::pip-24.0-pyhd8ed1ab_0
#   python             conda-forge/linux-64::python-3.8.5-h1103e12_9_cpython
#   readline           conda-forge/linux-64::readline-8.2-h8228510_1
#   setuptools         conda-forge/noarch::setuptools-71.0.4-pyhd8ed1ab_0
#   sqlite             conda-forge/linux-64::sqlite-3.46.0-h6d4b2fc_0
#   tk                 conda-forge/linux-64::tk-8.6.13-noxft_h4845f30_101
#   wheel              conda-forge/noarch::wheel-0.43.0-pyhd8ed1ab_1
#   xz                 conda-forge/linux-64::xz-5.2.6-h166bdaf_0
#   zlib               conda-forge/linux-64::zlib-1.2.13-h4ab18f5_6
#
#
#
# Downloading and Extracting Packages:
# python-3.8.5         | 21.9 MB   |                                       |   0%
# libstdcxx-ng-14.1.0  | 3.7 MB    |                                       |   0%
#
# openssl-1.1.1w       | 1.9 MB    |                                       |   0%
#
#
# setuptools-71.0.4    | 1.4 MB    |                                       |   0%
#
#
#
# pip-24.0             | 1.3 MB    |                                       |   0%
#
#
#
#
# ncurses-6.5          | 867 KB    |                                       |   0%
#
#
#
#
#
# sqlite-3.46.0        | 840 KB    |                                       |   0%
#
#
#
#
#
#
# libgcc-ng-14.1.0     | 822 KB    |                                       |   0%
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 691 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# libgomp-14.1.0       | 446 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 91 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libzlib-1.2.13       | 60 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.43.0         | 57 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.2.1         | 47 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 3 KB      |                                       |   0%
# python-3.8.5         | 21.9 MB   |                                       |   0%
#
# openssl-1.1.1w       | 1.9 MB    | 3                                     |   1%
#
#
# setuptools-71.0.4    | 1.4 MB    | 4                                     |   1%
#
#
#
# pip-24.0             | 1.3 MB    | 4                                     |   1%
# python-3.8.5         | 21.9 MB   | ####1                                 |  11%
#
#
#
#
# ncurses-6.5          | 867 KB    | 6                                     |   2%
#
#
#
#
#
# sqlite-3.46.0        | 840 KB    | 7                                     |   2%
#
#
#
#
#
#
# python-3.8.5         | 21.9 MB   | ############4                         |  34%
#
#
#
#
#
#
#
#
# libgomp-14.1.0       | 446 KB    | #3                                    |   4%
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 691 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 91 KB     | ######5                               |  18%
#
#
#
#
#
#
#
#
#
#
# libzlib-1.2.13       | 60 KB     | #########8                            |  27%
#
#
#
#
#
#
#
#
#
#
#
# python-3.8.5         | 21.9 MB   | ################                      |  44%
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.2.1         | 47 KB     | ############6                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.8.5         | 21.9 MB   | ##################################7   |  94%
#
# openssl-1.1.1w       | 1.9 MB    | ##################################### | 100%
#
# openssl-1.1.1w       | 1.9 MB    | ##################################### | 100%
#
#
# setuptools-71.0.4    | 1.4 MB    | ##################################### | 100%
#
#
# setuptools-71.0.4    | 1.4 MB    | ##################################### | 100%
#
#
#
# pip-24.0             | 1.3 MB    | ##################################### | 100%
#
#
#
# pip-24.0             | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
# sqlite-3.46.0        | 840 KB    | ##################################### | 100%
#
#
#
#
#
# sqlite-3.46.0        | 840 KB    | ##################################### | 100%
#
#
#
#
#
#
# libgcc-ng-14.1.0     | 822 KB    | ##################################### | 100%
#
#
#
#
#
#
# libgcc-ng-14.1.0     | 822 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libzlib-1.2.13       | 60 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libzlib-1.2.13       | 60 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 91 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 91 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# libgomp-14.1.0       | 446 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libgomp-14.1.0       | 446 KB    | ##################################### | 100%
# libstdcxx-ng-14.1.0  | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.43.0         | 57 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.43.0         | 57 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 691 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 691 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.2.1         | 47 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.2.1         | 47 KB     | ##################################### | 100%
#
#
#
#
# ncurses-6.5          | 867 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate /kaggle/working/FGVC/.conda
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# no change     /opt/conda/condabin/conda
# no change     /opt/conda/bin/conda
# no change     /opt/conda/bin/conda-env
# no change     /opt/conda/bin/activate
# no change     /opt/conda/bin/deactivate
# no change     /opt/conda/etc/profile.d/conda.sh
# no change     /opt/conda/etc/fish/conf.d/conda.fish
# no change     /opt/conda/shell/condabin/Conda.psm1
# no change     /opt/conda/shell/condabin/conda-hook.ps1
# no change     /opt/conda/lib/python3.10/site-packages/xontrib/conda.xsh
# no change     /opt/conda/etc/profile.d/conda.csh
# no change     /root/.bashrc
# No action taken.

# %%
# !unzip /kaggle/input/hand-video
# !mkdir results
# Out:
# unzip:  cannot find or open /kaggle/input/hand-video, /kaggle/input/hand-video.zip or /kaggle/input/hand-video.ZIP.

# %%
# !conda activate .conda
# !python --version
#!pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
#pip install cudatoolkit==10.1
#!pip install matplotlib scipy opencv-python
#pip install pytorch=1.6.0 torchvision=0.7.0 cudatoolkit=10.1 matplotlib scipy opencv -c pytorch
#!pip install imageio imageio-ffmpeg scikit-image imutils

#!chmod +x download_data_weights.sh
#!./download_data_weights.sh

#%cd tool
# !python video_completion.py \
       --mode object_removal \
       --path /kaggle/input/hand-video/frames \
       --path_mask /kaggle/input/hand-video/masks \
       --outroot results
# Out:
# CondaError: Run 'conda init' before 'conda activate'
#
# Python 3.10.13
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Calculating forward flow 1232 <---> 1233

# %% [markdown]
# Download weights and test images.

# %%
# !zip -r results.zip results

# %%
# %cd /content/FGVC/
# !chmod +x download_data_weights.sh
# !./download_data_weights.sh

# %% [markdown]
# Test the code

# %%
# %cd tool
# !python video_completion.py \
       --mode object_removal \
       --path /content/frames \
       --path_mask /content/masks \
       --outroot /results/ \
       --seamless
