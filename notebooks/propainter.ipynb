# %% [markdown]
# # ProPainter
# Clone the repo

# %%
# !git clone https://github.com/sczhou/ProPainter
# %cd ProPainter
# Out:
# Cloning into 'ProPainter'...
# remote: Enumerating objects: 601, done.
# remote: Counting objects: 100% (91/91), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 601 (delta 56), reused 47 (delta 44), pack-reused 510
# Receiving objects: 100% (601/601), 55.20 MiB | 46.18 MiB/s, done.
# Resolving deltas: 100% (89/89), done.
# /kaggle/working/ProPainter

# %% [markdown]
# Install dependencies

# %%
pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 40.8 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 51.4 MB/s eta 0:00:00:00:010:01m
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Run the code. Plz work.

# %%
# !python inference_propainter.py --video /kaggle/input/hands2/frames --mask /kaggle/input/hands2/masks
# Out:
# Downloading: "https://github.com/sczhou/ProPainter/releases/download/v0.1.0/raft-things.pth" to /kaggle/working/ProPainter/weights/raft-things.pth
#
# 100%|██████████████████████████████████████| 20.1M/20.1M [00:00<00:00, 69.1MB/s]
# Downloading: "https://github.com/sczhou/ProPainter/releases/download/v0.1.0/recurrent_flow_completion.pth" to /kaggle/working/ProPainter/weights/recurrent_flow_completion.pth
#
# 100%|██████████████████████████████████████| 19.4M/19.4M [00:00<00:00, 64.0MB/s]
# Pretrained flow completion model has loaded...
# Downloading: "https://github.com/sczhou/ProPainter/releases/download/v0.1.0/ProPainter.pth" to /kaggle/working/ProPainter/weights/ProPainter.pth
#
# 100%|█████████████████████████████████████████| 150M/150M [00:00<00:00, 213MB/s]
# Pretrained ProPainter has loaded...
# Network [InpaintGenerator] was created. Total number of parameters: 39.4 million. To see the architecture, do print(network).
#
# Processing: frames [1531 frames]...
# ...
